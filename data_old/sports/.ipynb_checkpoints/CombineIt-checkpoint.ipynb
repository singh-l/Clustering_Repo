# %%
import os
import random
import glob
import pandas as pd
#os.chdir('/Users/lovedeepsingh/Desktop/TWITTER/Clustering')

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
#combine all files in the list
class_combined = pd.concat([pd.read_csv(f) for f in all_filenames ])
df = class_combined

# %%
df
# Out:
#      Unnamed: 0                                               text  \
# 0             0  Virat Kohli \n#TrovoIndia #PredictManOfTheMatc...
# 1             1  Big shout out to @Qdoscricket replacing one of...
# 2             2  Cool\n.\n.\n.\nUlta Cool\n.\n.\n.\nYuzvendra-C...
# 3             3  New Zealand, Batting score (177-1)\n\n#Contest...
# 4             4  2019 U19 Asia Cup:\n1st SEMI FINAL,\n India U1...
# ..          ...                                                ...
# 495         495  Mayor's report: #Houston awaits word next week...
# 496         496  #TableTennis For Jun Wu V Yun Qing Zhang on Th...
# 497         497  #tabletennis 2 doubles pairs into the semis in...
# 498         498  Benjamin and Reuben enjoyed their training day...
# 499         499  #TableTennis For Kristian Karlsson V Pavel Sir...
#
#            class
# 0        cricket
# 1        cricket
# 2        cricket
# 3        cricket
# 4        cricket
# ..           ...
# 495  tabletennis
# 496  tabletennis
# 497  tabletennis
# 498  tabletennis
# 499  tabletennis
#
# [2500 rows x 3 columns]

# %%
#combine all files in the list
#combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#shuffle
#random.shuffle(combined_csv)
#export to csv
df.to_csv( "class_combined.csv", index=False, encoding='utf-8-sig')

# %%
df=pd.read_csv('class_combined.csv',usecols=["text","class"])

# %%
df
# Out:
#                                                    text        class
# 0     Virat Kohli \n#TrovoIndia #PredictManOfTheMatc...      cricket
# 1     Big shout out to @Qdoscricket replacing one of...      cricket
# 2     Cool\n.\n.\n.\nUlta Cool\n.\n.\n.\nYuzvendra-C...      cricket
# 3     New Zealand, Batting score (177-1)\n\n#Contest...      cricket
# 4     2019 U19 Asia Cup:\n1st SEMI FINAL,\n India U1...      cricket
# ...                                                 ...          ...
# 2495  Mayor's report: #Houston awaits word next week...  tabletennis
# 2496  #TableTennis For Jun Wu V Yun Qing Zhang on Th...  tabletennis
# 2497  #tabletennis 2 doubles pairs into the semis in...  tabletennis
# 2498  Benjamin and Reuben enjoyed their training day...  tabletennis
# 2499  #TableTennis For Kristian Karlsson V Pavel Sir...  tabletennis
#
# [2500 rows x 2 columns]

# %%
df.to_csv( "class_combined.csv", index=False, encoding='utf-8-sig')
